# %% [markdown]
# <a href="https://colab.research.google.com/github/gusdesindu/Latihan-1/blob/main/Latihan_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 5 nama mahasiswa

# %%
mahasiswa = ["andi", "budi", "kipli", "rehan"]
print("List Mahasiswa")
print(mahasiswa)
# Out:
# List Mahasiswa
# ['andi', 'budi', 'kipli', 'rehan']

# %% [markdown]
# tambah dengan append

# %%
mahasiswa.append("Gata")
print("setelah nambah nama baru")
print(mahasiswa)
# Out:
# setelah nambah nama baru
# ['andi', 'budi', 'kipli', 'rehan', 'budi', 'budi', 'Gata', 'Gata', 'Gata', 'Gata']

# %% [markdown]
# menghapis satu elemen menggunakan remova

# %%
mahasiswa.remove("kipli")
print("setelah hapus nama ")
print(mahasiswa)
# Out:
# setelah hapus nama
# ['andi', 'budi', 'rehan', 'budi', 'budi', 'Gata', 'Gata', 'Gata', 'Gata']
